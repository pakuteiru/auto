# %%
city_list = ['shibuya','yokohama','kyoto','osaka']

# %%
#初回のみインストールする
# !pip install KeplerGl;

#ライブラリ
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import keplergl
from keplergl import KeplerGl
#表示行列を設定
project_id = 'luup-prod' #プロジェクトIDを設定
today = datetime.date.today() #今日の日付
thirty_days_ago = today-datetime.timedelta(days=30) #30日前の日付

# %%
lat ={'yokohama': 35.450792162369595,
      'shibuya': 35.66862563407147,
       'kyoto': 35.00728420000003,
      'osaka': 34.67864230069687
      }
lng = {'yokohama': 139.62903207672306,
       'shibuya': 139.71289860000124,
        'kyoto': 135.76012589787263,
        'osaka': 135.50176776138105
       }

# %%
for city_name in city_list:
    df_ride =pd.read_csv(f'/Users/pakuteiru/Desktop/定期実行/ride/ride_{city_name}.csv')
    df_port =pd.read_csv(f'/Users/pakuteiru/Desktop/定期実行/port/port_{city_name}.csv')

    df_start = df_ride.groupby('start_port_id').sum()['payment_amount_tax_excluded'].reset_index()
    df_end = df_ride.groupby('end_port_id').sum()['payment_amount_tax_excluded'].reset_index()
    df = pd.merge(df_start,df_end,left_on='start_port_id',right_on='end_port_id')
    df['MARPP'] = (df['payment_amount_tax_excluded_x']+df['payment_amount_tax_excluded_y'])/2
    df['start_port_id'] = df['start_port_id'].astype('int')
    df = df.rename(columns={'start_port_id': 'port_id'})[['port_id','MARPP']]
    df_marpp = pd.merge(df_port,df,on='port_id')
    df_marpp['net_income'] = df_marpp['MARPP']-df_marpp['payment_amount']


    config = {'version': 'v1',
     'config': {'visState': {'filters': [],
       'layers': [{'id': '1iaeink',
         'type': 'point',
         'config': {'dataId': 'marpp',
          'label': 'port',
          'color': [18, 147, 154],
          'highlightColor': [252, 242, 26, 255],
          'columns': {'lat': 'lat', 'lng': 'lng', 'altitude': None},
          'isVisible': True,
          'visConfig': {'radius': 10,
           'fixedRadius': False,
           'opacity': 0.8,
           'outline': False,
           'thickness': 2,
           'strokeColor': None,
           'colorRange': {'name': 'Uber Viz Diverging 3.5',
            'type': 'diverging',
            'category': 'Uber',
            'colors': ['#C22E00',
             '#D0532B',
             '#DD7755',
             '#EB9C80',
             '#F8C0AA',
             '#BAE1E2',
             '#8CCED1',
             '#5DBABF',
             '#2FA7AE',
             '#00939C'],
            'reversed': True},
           'strokeColorRange': {'name': 'Global Warming',
            'type': 'sequential',
            'category': 'Uber',
            'colors': ['#5A1846',
             '#900C3F',
             '#C70039',
             '#E3611C',
             '#F1920E',
             '#FFC300']},
           'radiusRange': [0, 50],
           'filled': True},
          'hidden': False,
          'textLabel': [{'field': None,
            'color': [255, 255, 255],
            'size': 18,
            'offset': [0, 0],
            'anchor': 'start',
            'alignment': 'center'}]},
         'visualChannels': {'colorField': {'name': 'net_income', 'type': 'real'},
          'colorScale': 'quantile',
          'strokeColorField': None,
          'strokeColorScale': 'quantile',
          'sizeField': {'name': 'MARPP', 'type': 'real'},
          'sizeScale': 'sqrt'}}],
       'interactionConfig': {'tooltip': {'fieldsToShow': {'marpp': [{'name': 'port_name',
            'format': None},
           {'name': 'installation_day', 'format': None},
           {'name': 'station', 'format': None},
           {'name': 'capacity', 'format': None},
           {'name': 'MARPP', 'format': None},
           {'name': 'payment_amount', 'format': None},
           {'name': 'net_income', 'format': None}]},
         'compareMode': False,
         'compareType': 'absolute',
         'enabled': True},
        'brush': {'size': 0.5, 'enabled': False},
        'geocoder': {'enabled': False},
        'coordinate': {'enabled': False}},
       'layerBlending': 'normal',
       'splitMaps': [],
       'animationConfig': {'currentTime': None, 'speed': 1}},
      'mapState': {'bearing': 0,
       'dragRotate': False,
       'latitude': lat[city_name],
       'longitude': lng[city_name],
       'pitch': 0,
       'zoom': 12.174832746508802,
       'isSplit': False},
      'mapStyle': {'styleType': 'fkaoowi',
       'topLayerGroups': {},
       'visibleLayerGroups': {'label': True,
        'road': True,
        'building': True,
        'water': True,
        'land': True},
       'threeDBuildingColor': [194.6103322548211,
        191.81688250953655,
        185.2988331038727],
       'mapStyles': {'fkaoowi': {'accessToken': 'pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA',
         'custom': True,
         'icon': 'https://api.mapbox.com/styles/v1/yumao0116/cl4qd0vkt000914qnhqdlroqr/static/-122.3391,37.7922,9,0,0/400x300?access_token=pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA&logo=false&attribution=false',
         'id': 'fkaoowi',
         'label': 'Mapbox Streets Japan',
         'url': 'mapbox://styles/yumao0116/cl4qd0vkt000914qnhqdlroqr'}}}}}

    config_minus = {'version': 'v1',
     'config': {'visState': {'filters': [{'dataId': ['marpp'],
         'id': '3tdjz3t5',
         'name': ['net_income'],
         'type': 'range',
         'value': [-9999999, 0],
         'enlarged': False,
         'plotType': 'histogram',
         'animationWindow': 'free',
         'yAxis': None,
         'speed': 1}],
       'layers': [{'id': '1iaeink',
         'type': 'point',
         'config': {'dataId': 'marpp',
          'label': 'port',
          'color': [18, 147, 154],
          'highlightColor': [252, 242, 26, 255],
          'columns': {'lat': 'lat', 'lng': 'lng', 'altitude': None},
          'isVisible': True,
          'visConfig': {'radius': 10,
           'fixedRadius': False,
           'opacity': 0.8,
           'outline': False,
           'thickness': 2,
           'strokeColor': None,
           'colorRange': {'name': 'ColorBrewer YlOrRd-6',
            'type': 'sequential',
            'category': 'ColorBrewer',
            'colors': ['#bd0026',
             '#f03b20',
             '#fd8d3c',
             '#feb24c',
             '#fed976',
             '#ffffb2'],
            'reversed': True},
           'strokeColorRange': {'name': 'Global Warming',
            'type': 'sequential',
            'category': 'Uber',
            'colors': ['#5A1846',
             '#900C3F',
             '#C70039',
             '#E3611C',
             '#F1920E',
             '#FFC300']},
           'radiusRange': [0, 50],
           'filled': True},
          'hidden': False,
          'textLabel': [{'field': None,
            'color': [255, 255, 255],
            'size': 18,
            'offset': [0, 0],
            'anchor': 'start',
            'alignment': 'center'}]},
         'visualChannels': {'colorField': {'name': 'net_income', 'type': 'real'},
          'colorScale': 'quantile',
          'strokeColorField': None,
          'strokeColorScale': 'quantile',
          'sizeField': {'name': 'MARPP', 'type': 'real'},
          'sizeScale': 'sqrt'}}],
       'interactionConfig': {'tooltip': {'fieldsToShow': {'marpp': [{'name': 'port_name',
            'format': None},
           {'name': 'installation_day', 'format': None},
           {'name': 'station', 'format': None},
           {'name': 'capacity', 'format': None},
           {'name': 'MARPP', 'format': None},
           {'name': 'payment_amount', 'format': None},
           {'name': 'net_income', 'format': None}]},
         'compareMode': False,
         'compareType': 'absolute',
         'enabled': True},
        'brush': {'size': 0.5, 'enabled': False},
        'geocoder': {'enabled': False},
        'coordinate': {'enabled': False}},
       'layerBlending': 'normal',
       'splitMaps': [],
       'animationConfig': {'currentTime': None, 'speed': 1}},
      'mapState': {'bearing': 0,
       'dragRotate': False,
       'latitude': lat[city_name],
       'longitude': lng[city_name],
       'pitch': 0,
       'zoom': 12.043232505593107,
       'isSplit': False},
      'mapStyle': {'styleType': 'fkaoowi',
       'topLayerGroups': {},
       'visibleLayerGroups': {'label': True,
        'road': True,
        'building': True,
        'water': True,
        'land': True},
       'threeDBuildingColor': [194.6103322548211,
        191.81688250953655,
        185.2988331038727],
       'mapStyles': {'fkaoowi': {'accessToken': 'pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA',
         'custom': True,
         'icon': 'https://api.mapbox.com/styles/v1/yumao0116/cl4qd0vkt000914qnhqdlroqr/static/-122.3391,37.7922,9,0,0/400x300?access_token=pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA&logo=false&attribution=false',
         'id': 'fkaoowi',
         'label': 'Mapbox Streets Japan',
         'url': 'mapbox://styles/yumao0116/cl4qd0vkt000914qnhqdlroqr'}}}}}

    config_plus = {'version': 'v1',
     'config': {'visState': {'filters': [{'dataId': ['marpp'],
         'id': '3tdjz3t5',
         'name': ['net_income'],
         'type': 'range',
         'value': [0,9999999],
         'enlarged': False,
         'plotType': 'histogram',
         'animationWindow': 'free',
         'yAxis': None,
         'speed': 1}],
       'layers': [{'id': '1iaeink',
         'type': 'point',
         'config': {'dataId': 'marpp',
          'label': 'port',
          'color': [18, 147, 154],
          'highlightColor': [252, 242, 26, 255],
          'columns': {'lat': 'lat', 'lng': 'lng', 'altitude': None},
          'isVisible': True,
          'visConfig': {'radius': 10,
           'fixedRadius': False,
           'opacity': 0.8,
           'outline': False,
           'thickness': 2,
           'strokeColor': None,
           'colorRange': {'name': 'ColorBrewer Blues-6',
            'type': 'singlehue',
            'category': 'ColorBrewer',
            'colors': ['#eff3ff',
             '#c6dbef',
             '#9ecae1',
             '#6baed6',
             '#3182bd',
             '#08519c'],
            'reversed': False},
           'strokeColorRange': {'name': 'Global Warming',
            'type': 'sequential',
            'category': 'Uber',
            'colors': ['#5A1846',
             '#900C3F',
             '#C70039',
             '#E3611C',
             '#F1920E',
             '#FFC300']},
           'radiusRange': [0, 50],
           'filled': True},
          'hidden': False,
          'textLabel': [{'field': None,
            'color': [255, 255, 255],
            'size': 18,
            'offset': [0, 0],
            'anchor': 'start',
            'alignment': 'center'}]},
         'visualChannels': {'colorField': {'name': 'net_income', 'type': 'real'},
          'colorScale': 'quantile',
          'strokeColorField': None,
          'strokeColorScale': 'quantile',
          'sizeField': {'name': 'MARPP', 'type': 'real'},
          'sizeScale': 'sqrt'}}],
       'interactionConfig': {'tooltip': {'fieldsToShow': {'marpp': [{'name': 'port_name',
            'format': None},
           {'name': 'installation_day', 'format': None},
           {'name': 'station', 'format': None},
           {'name': 'capacity', 'format': None},
           {'name': 'MARPP', 'format': None},
           {'name': 'payment_amount', 'format': None},
           {'name': 'net_income', 'format': None}]},
         'compareMode': False,
         'compareType': 'absolute',
         'enabled': True},
        'brush': {'size': 0.5, 'enabled': False},
        'geocoder': {'enabled': False},
        'coordinate': {'enabled': False}},
       'layerBlending': 'normal',
       'splitMaps': [],
       'animationConfig': {'currentTime': None, 'speed': 1}},
      'mapState': {'bearing': 0,
       'dragRotate': False,
       'latitude': lat[city_name],
       'longitude': lng[city_name],
       'pitch': 0,
       'zoom': 12.043232505593107,
       'isSplit': False},
      'mapStyle': {'styleType': 'fkaoowi',
       'topLayerGroups': {},
       'visibleLayerGroups': {'label': True,
        'road': True,
        'building': True,
        'water': True,
        'land': True},
       'threeDBuildingColor': [194.6103322548211,
        191.81688250953655,
        185.2988331038727],
       'mapStyles': {'fkaoowi': {'accessToken': 'pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA',
         'custom': True,
         'icon': 'https://api.mapbox.com/styles/v1/yumao0116/cl4qd0vkt000914qnhqdlroqr/static/-122.3391,37.7922,9,0,0/400x300?access_token=pk.eyJ1IjoieXVtYW8wMTE2IiwiYSI6ImNrd29lN2FpODAyMDEyb3Bta3Z1N3ViNHQifQ.9bYDPTphEaefGY0LEFF_IA&logo=false&attribution=false',
         'id': 'fkaoowi',
         'label': 'Mapbox Streets Japan',
         'url': 'mapbox://styles/yumao0116/cl4qd0vkt000914qnhqdlroqr'}}}}}

    #全体のMARPP
    map_marpp = KeplerGl(height=600,width=600,data={"marpp":df_marpp}, show_docs=False,config=config)
    #赤字のポート
    map_minus = KeplerGl(height=600,width=600,data={"marpp":df_marpp}, show_docs=False,config=config_minus)
    #黒字のポート
    map_plus = KeplerGl(height=600,width=600,data={"marpp":df_marpp}, show_docs=False,config=config_plus)

    map_marpp.save_to_html(file_name=f'/Users/pakuteiru/Desktop/定期実行/MARPP/{city_name}/marpp_all.html')
    map_plus.save_to_html(file_name=f'/Users/pakuteiru/Desktop/定期実行/MARPP/{city_name}/marpp_plus.html')
    map_minus.save_to_html(file_name=f'/Users/pakuteiru/Desktop/定期実行/MARPP/{city_name}/marpp_minus.html')
# Out:
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/shibuya/marpp_all.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/shibuya/marpp_plus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/shibuya/marpp_minus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/yokohama/marpp_all.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/yokohama/marpp_plus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/yokohama/marpp_minus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/kyoto/marpp_all.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/kyoto/marpp_plus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/kyoto/marpp_minus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/osaka/marpp_all.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/osaka/marpp_plus.html!
# Map saved to /Users/pakuteiru/Desktop/定期実行/MARPP/osaka/marpp_minus.html!
